# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:wohvUp-tyddyr-gufpy0@/fin_data_db?unix_socket=/cloudsql/findata-etl:us-central1:fin-data-sql')

with engine.connect() as connection:
    result = connection.execute("SELECT * FROM table_name LIMIT 10")
    for row in result:
        print(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Financial_data_ETL/.venv/lib/python3.11/site-packages/pymysql/connections.py:605, in Connection.connect(self, sock)
#     604 sock.settimeout(self.connect_timeout)
# --> 605 sock.connect(self.unix_socket)
#     606 self.host_info = "Localhost via UNIX socket"
#
# FileNotFoundError: [Errno 2] No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File ~/Financial_data_ETL/.venv/lib/python3.11/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# ...
